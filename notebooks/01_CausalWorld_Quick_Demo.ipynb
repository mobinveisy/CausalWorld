# %% [markdown]
# # CausalWorld — Quick Demo
#
# A short sanity run of the causally editable latent-physics pipeline.
#
# **This notebook is a demo, not a source of final paper numbers.**

# %%
GITHUB_REPO = "mobinveisy/CausalWorld"
BRANCH = "main"
# !git clone -b {BRANCH} https://github.com/{GITHUB_REPO}.git
# %cd CausalWorld
# !pip -q install -e .

# %%
# !python run_tests.py

# %%
# !python run_experiment.py \
  --model causal \
  --epochs 5 \
  --samples 700 \
  --eval-samples 220 \
  --seed 11 \
  --output outputs/colab_demo

# %% [markdown]
# The main causal metric is **CEE — Counterfactual Effect Error**; lower is better.
