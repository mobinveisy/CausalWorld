# %% [markdown]
# # Reproduce CausalWorld
#
# Full synthetic suite + public-data setup entry point.

# %%
GITHUB_REPO = "YOUR_GITHUB_USER/CausalWorld"
# !git clone https://github.com/{GITHUB_REPO}.git
# %cd CausalWorld
# !pip -q install -e .

# %%
# !python run_suite.py \
  --mode full \
  --seeds 11 22 33 44 55 \
  --output results_full

# %%
# !python make_report.py \
  --csv results_full/results.csv \
  --output paper_assets_full

# %% [markdown]
# ## Public data

# %%
# Uncomment when needed:
# !python public_data/download_public_data.py physion-train
# !python public_data/download_public_data.py physion-readout
# !python public_data/download_public_data.py physion-test
# !python public_data/download_public_data.py gauge-rigid-json
